# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
X = np.linspace(-2, 2, 7)
y = X ** 3 # original dependecy 

plt.scatter(X, y)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$');

# %%
y
# Out:
# array([-8.        , -2.37037037, -0.2962963 ,  0.        ,  0.2962963 ,
#         2.37037037,  8.        ])

# %%
X
# Out:
# array([-2.        , -1.33333333, -0.66666667,  0.        ,  0.66666667,
#         1.33333333,  2.        ])

# %%
df = pd.DataFrame(np.array([X, y]).transpose(),columns=['X', 'y'])

# %%
df.head()
# Out:
#           X         y
# 0 -2.000000 -8.000000
# 1 -1.333333 -2.370370
# 2 -0.666667 -0.296296
# 3  0.000000  0.000000
# 4  0.666667  0.296296

# %%
df.plot(kind='scatter',x='X',y='y',color='red')
plt.show()

# %%
def func(data):
    df.plot(kind='line',x='X',y='y',color='red')
    plt.show()
func(df)

# %%
data1=df[df['X']<0]
data2=df[df['X']>=0]

# %%
data1.plot(kind='scatter',x='X',y='y',color='red')
data2.plot(kind='scatter',x='X',y='y',color='yellow')

# %%
reg_tree_pred = df.predict(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4fa9671ae665> in <module>
# ----> 1 reg_tree_pred = df.predict(X)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'predict'
