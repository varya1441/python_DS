# %%
import pandas as pd
import numpy as np

# Disable warnings
import warnings
warnings.filterwarnings("ignore")

# Import plotting modules
import seaborn as sns
sns.set()
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker
# %matplotlib inline

# %%
# Tune the visual settings for figures in `seaborn`
sns.set_context(
    "notebook", 
    font_scale=1.5,       
    rc={ 
        "figure.figsize": (11, 8), 
        "axes.titlesize": 18 
    }
)

from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 8

# %%
df = pd.read_csv('C:/Users/varvara tihonova/mlcourse.ai/data/mlbootcamp5_train.csv', sep=';')
#print('Dataset size: ', df.shape)

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df_uniques = pd.melt(frame=df, value_vars=['gender','cholesterol', 
                                           'gluc', 'smoke', 'alco', 
                                           'active', 'cardio'])
df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 
                                              'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

sns.factorplot(x='variable', y='count', hue='value', 
               data=df_uniques, kind='bar', size=12);

# %%
df_uniques = pd.melt(frame=df, value_vars=['gender','cholesterol', 
                                           'gluc', 'smoke', 'alco', 
                                           'active'], 
                     id_vars=['cardio'])
df_uniques = pd.DataFrame(df_uniques.groupby(['variable', 'value', 
                                              'cardio'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

sns.factorplot(x='variable', y='count', hue='value', 
               col='cardio', data=df_uniques, kind='bar', size=9);

# %%
for c in df.columns:
    n = df[c].nunique()
    print(c)
    if n <= 3:
        print(n, sorted(df[c].value_counts().to_dict().items()))
    else:
        print(n)
    print(10 * '-')
# Out:
# id
# 70000
# ----------
# age
# 8076
# ----------
# gender
# 2 [(1, 45530), (2, 24470)]
# ----------
# height
# 109
# ----------
# weight
# 287
# ----------
# ap_hi
# 153
# ----------
# ap_lo
# 157
# ----------
# cholesterol
# 3 [(1, 52385), (2, 9549), (3, 8066)]
# ----------
# gluc
# 3 [(1, 59479), (2, 5190), (3, 5331)]
# ----------
# smoke
# 2 [(0, 63831), (1, 6169)]
# ----------
# alco
# 2 [(0, 66236), (1, 3764)]
# ----------
# active
# 2 [(0, 13739), (1, 56261)]
# ----------
# cardio
# 2 [(0, 35021), (1, 34979)]
# ----------

# %%
df.height.mean()
# Out:
# 164.35922857142856

# %%
df.groupby('gender')['height'].mean()
# Out:
# gender
# 1    161.355612
# 2    169.947895
# Name: height, dtype: float64

# %%
df.groupby('gender')['alco'].mean()
# Out:
# gender
# 1    0.025500
# 2    0.106375
# Name: alco, dtype: float64

# %%
df.groupby('gender')['smoke'].mean()
# Out:
# gender
# 1    0.017856
# 2    0.218880
# Name: smoke, dtype: float64

# %%
round(100 * (df.loc[df['gender'] == 2, 'smoke'].mean() - df.loc[df['gender'] == 1, 'smoke'].mean()))
# Out:
# 20

# %%
(df[df['smoke'] == 0]['age'].median() - 
 df[df['smoke'] == 1]['age'].median()) /365.25*12
# Out:
# 19.613963039014372

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
stepik=pd.read_csv('C:/Users/varvara tihonova/Downloads/статистика/cats.csv')

# %%
stepik[stepik['lunch']=='free/reduced'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lunch'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-9e8c79c7c9f1> in <module>
# ...

# %%
stepik.columns

# %%
stepik=stepik \
        .rename(columns = {
     'parental level of education':'parental_level_of_education', 
       'test preparation course': 'test_preparation_course',
    'math score':'math_score', 
    'reading score':'reading_score',
       'writing score':'writing_score'})

# %%
stepik.head()

# %%
stepik.query("gender=='female'&math_score>70").count()-stepik.query("gender!='female'&math_score>70").count()

# %%
stepik.head(10)
# Out:
#    Unnamed: 0  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0           0         1        1                   0  собачка
# 1           1         1        1                   0  собачка
# 2           2         1        1                   0  собачка
# 3           3         1        1                   0  собачка
# 4           4         1        0                   1    котик
# 5           5         1        0                   1    котик
# 6           6         1        0                   1    котик
# 7           7         1        0                   1    котик
# 8           8         1        1                   1    котик
# 9           9         0        0                   1    котик

# %%
dt=pd.DataFrame()

# %%
dt['X1']=stepik['Шерстист']

# %%
dt["X2"] = stepik['Гавкает']

dt["X3"] = stepik['Лазает по деревьям']
dt["Y"] = stepik['Вид']

# %%
import scipy.stats as sts
def entr(p1,p2):
    return - (p1*math.log(p1,2)+ p2*math.log(p2,2))
for col in dt.columns[1:4]:
    print(col, round())

# %%
from __future__ import division, print_function
# отключим всякие предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt

# %%
def build(L):
    create node t
    if the stopping criterion is True:
        assign a predictive model to t
    else:
        Find the best binary split L = L_left + L_right
        t.left = build(L_left)
        t.right = build(L_right)
    return t
# Out:
#   File "<ipython-input-2-919e5a4e342d>", line 2
#     create node t
#               ^
# SyntaxError: invalid syntax

# %%
plt.rcParams['figure.figsize'] = (6,4)
xx = np.linspace(0,1,50)
plt.plot(xx, [2 * x * (1-x) for x in xx], label='gini')
plt.plot(xx, [4 * x * (1-x) for x in xx], label='2*gini')
plt.plot(xx, [-x * np.log2(x) - (1-x) * np.log2(1 - x)  for x in xx], label='entropy')
plt.plot(xx, [1 - max(x, 1-x) for x in xx], label='missclass')
plt.plot(xx, [2 - 2 * max(x, 1-x) for x in xx], label='2*missclass')
plt.xlabel('p+')
plt.ylabel('criterion')
plt.title('Критерии качества как функции от p+ (бинарная классификация)')
plt.legend();

# %%
# first class
np.random.seed(17)
train_data = np.random.normal(size=(100, 2))
train_labels = np.zeros(100)

# adding second class
train_data = np.r_[train_data, np.random.normal(size=(100, 2), loc=2)]
train_labels = np.r_[train_labels, np.ones(100)]

# %%
plt.figure(figsize=(10,8))
plt.scatter(train_data[:, 0], train_data[:, 1], c=train_labels, s=100, 
cmap='autumn', edgecolors='black', linewidth=1.5);
plt.plot(range(-2,5), range(4,-3,-1));

# %%
from sklearn.tree import DecisionTreeClassifier

# Let’s write an auxiliary function that will return grid for further visualization.
def get_grid(data):
    x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
    y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
    return np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

clf_tree = DecisionTreeClassifier(criterion='entropy', max_depth=3, 
                                  random_state=17)

# training the tree
clf_tree.fit(train_data, train_labels)

# some code to depict separating surface
xx, yy = get_grid(train_data)
predicted = clf_tree.predict(np.c_[xx.ravel(), 
                                   yy.ravel()]).reshape(xx.shape)
plt.pcolormesh(xx, yy, predicted, cmap='autumn')
plt.scatter(train_data[:, 0], train_data[:, 1], c=train_labels, s=100, 
            cmap='autumn', edgecolors='black', linewidth=1.5);

# %%
import pydotplus #pip install pydotplus
from sklearn.tree import export_graphviz

def tree_graph_to_png(tree, feature_names, png_file_to_save):
    tree_str = export_graphviz(tree, feature_names=feature_names, 
                                     filled=True, out_file=None)
    graph = pydotplus.graph_from_dot_data(tree_str)  
    graph.write_png(png_file_to_save)

# %%
tree_graph_to_png(tree=clf_tree, feature_names=['x1', 'x2'], 
                  png_file_to_save='C:/Users/varvara tihonova/mlcourse.ai/img/topic3_decision_tree1.png')

# %%
data = pd.DataFrame({'Age': [17,64,18,20,38,49,55,25,29,31,33],
                     'Loan Default': [1,0,1,0,1,0,0,1,1,0,1]})
data
# Out:
#     Age  Loan Default
# 0    17             1
# 1    64             0
# 2    18             1
# 3    20             0
# 4    38             1
# 5    49             0
# 6    55             0
# 7    25             1
# 8    29             1
# 9    31             0
# 10   33             1

# %%
data.sort_values('Age')
# Out:
#     Age  Loan Default
# 0    17             1
# 2    18             1
# 3    20             0
# 7    25             1
# 8    29             1
# 9    31             0
# 10   33             1
# 4    38             1
# 5    49             0
# 6    55             0
# 1    64             0

# %%
age_tree = DecisionTreeClassifier(random_state=17)
age_tree.fit(data['Age'].values.reshape(-1, 1), data['Loan Default'].values)

tree_graph_to_png(age_tree, feature_names=['Age'], 
                 png_file_to_save='C:/Users/varvara tihonova/mlcourse.ai/img/vvv.png')

# %%
import numpy as np

# %%
-(5/9)*np.log2(5/9)-(4/9)*np.log(4/9)
# Out:
# 0.8315228219600073

# %%
def fun(p1,p2):
    return -(p1*np.log2(p1)+p2*np.log2(p2))
fun(9/20,11/20)-(1/20)*(9*fun((4/9),(5/9))+11*fun((5/11),(6/11)))
# Out:
# 7.361074828204917e-05

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data
y = iris.target

# %%
clf_tree = DecisionTreeClassifier(criteria='entropy' ,max_depth=4, 
                                  random_state=17)

# %%
clf_tree.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=17, splitter='best')

# %%
tree_graph_to_png(clf_tree, feature_names=['sepal length', 'sepal width ','petal length' , 'petal width'], 
                 png_file_to_save='C:/Users/varvara tihonova/mlcourse.ai/img/v.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     104         try:
# --> 105             return self[key]
#     106         except KeyError:
#
# KeyError: 'classes'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-68571ac5401a> in <module>
# ----> 1 iris.classes
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     105             return self[key]
#     106         except KeyError:
# --> 107             raise AttributeError(key)
#     108
#     109     def __setstate__(self, state):
#
# AttributeError: classes

# %%
graph=Source(tree.export_graphviz(clf_tree, out_file = None
                                 ,feature_names =['sepal length', 'sepal width ','petal length' , 'petal width']
                            
                                 ,filled = True))
display(SVG(graph.pipe(format='svg')))

# %%
stepik.head(11)
# Out:
#    Unnamed: 0  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0           0         1        1                   0  собачка
# 1           1         1        1                   0  собачка
# 2           2         1        1                   0  собачка
# 3           3         1        1                   0  собачка
# 4           4         1        0                   1    котик
# 5           5         1        0                   1    котик
# 6           6         1        0                   1    котик
# 7           7         1        0                   1    котик
# 8           8         1        1                   1    котик
# 9           9         0        0                   1    котик

# %%
stepik.query("Гавкает==0&Вид=='собачка'").count()
# Out:
# Unnamed: 0            0
# Шерстист              0
# Гавкает               0
# Лазает по деревьям    0
# Вид                   0
# dtype: int64

# %%
fun((6/10),(4/10))
# Out:
# 0.9709505944546686

# %%
titanic=pd.read_csv('C:/Users/varvara tihonova/Downloads/статистика/train.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
# %matplotlib inline

from graphviz  import Source
from IPython.display import SVG, display, HTML
style = "<style>svg{width: 70% !important; height: 60% !important;} </style>"

# %%
X.isnull().sum()
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
X=titanic.drop(['PassengerId','Ticket','Survived','Cabin','Name'],axis=1)

# %%
X.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %%
y=titanic.Survived
X=pd.get_dummies(X)
X=X.fillna({'Age':X.Age.median()})

# %%
clf=tree.DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
graph=Source(tree.export_graphviz(clf, out_file = None
                                 ,feature_names = list(X),class_names=['Died','Survived']
                                 ,filled = True))
display(SVG(graph.pipe(format='svg')))

# %%
print(iris.target_names)
from sklearn.model_selection
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
clf.score(X,y)
# Out:
# 0.9797979797979798

# %%
heart=pd.read_csv('C:/Users/varvara tihonova/Downloads/статистика/heart.csv')

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
from sklearn.ensemble import RandomForestClassifier
np.random.seed(0)

rf = RandomForestClassifier(10, max_depth=5)

# %%
imp = pd.DataFrame(rf.feature_importances_, index=x_train.columns, columns=['importance'])
imp.sort_values('importance').plot(kind='barh', figsize=(12, 8))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-139-ef9f98ba8151> in <module>
# ----> 1 imp = pd.DataFrame(rf.feature_importances_, index=x_train.columns, columns=['importance'])
#       2 imp.sort_values('importance').plot(kind='barh', figsize=(12, 8))
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in feature_importances_(self)
#     371             array of zeros.
#     372         """
# --> 373         check_is_fitted(self, 'estimators_')
#     374
#     375         all_importances = Parallel(n_jobs=self.n_jobs,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# ...

# %%
X=heart.values

# %%
y=heart.sex

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
from sklearn.model_selection import GridSearchCV
parameters = { 'max_depth': [5],'n_estimators':[10]}

# %%
r_f=GridSearchCV(rf, parameters,cv=5)

# %%
r_f.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=5,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
# ...

# %%
best_rf=r_f.best_estimator_
feature_importances=best_rf.feature_importances_
X.size
# Out:
# 4242

# %%
feature_importances_df=pd.DataFrame({'features':list(X),
                                'feature_importances':feature_importances})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-3ead1604fa7d> in <module>
#       1 feature_importances_df=pd.DataFrame({'features':list(X_train),
# ----> 2                                 'feature_importances':feature_importances})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# ...

# %%
imp = pd.DataFrame(r_f.feature_importances_, index=X.columns, columns=['importance'])
imp.sort_values('importance').plot(kind='barh', figsize=(12, 8))

# %%
str=input()
# Out:
# 12

# %%
import math

# %%
a = int(input())
# Out:
# 10

# %%
b = int(input())
# Out:
# 9

# %%
if (b*math.log10(a)/10)>(a*math.log10(b)/10):
    print(">")
else:
    print("<")
# Out:
# <
